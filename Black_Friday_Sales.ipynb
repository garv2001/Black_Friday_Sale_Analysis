# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("BlackFriday.csv")
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 537572                 2.0                 NaN     11664
# 537573                15.0                16.0     19196
# 537574                15.0                 NaN      8043
# 537575                 NaN                 NaN      7172
# 537576                 8.0                 NaN      6875
#
# [537577 rows x 12 columns]

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %% [markdown]
# ### Null values are present in column 9 and 10

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# ### Deleting those 2 columns as deleting the rowa will remove approx 60 percent of the data

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
for column in df.columns:
    print(column,":",df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# ## Insights From Gender

# %%
df[df["Gender"]== "M"]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# 5                               3               0                   1
# 6                               2               1                   1
# 7                               2               1                   1
# 8                               2               1                   1
# ...                           ...             ...                 ...
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Purchase
# 4           7969
# 5          15227
# 6          19215
# 7          15854
# 8          15686
# ...          ...
# 537572     11664
# 537573     19196
# 537574      8043
# 537575      7172
# 537576      6875
#
# [405380 rows x 10 columns]

# %%
data=pd.DataFrame({"Ratio":[len(df[df["Gender"]=="M"]),len(df[df["Gender"]=="F"])]},index=["Male","Female"])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot(kind="pie",y="Ratio",autopct="%.1f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby("Gender").size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby("Gender").size().plot(kind="bar",figsize=(6,6))
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# ### Amount spent by each gender

# %%
df.groupby("Gender").sum()["Purchase"]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\2627663225.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Gender").sum()["Purchase"]
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby("Gender").sum()["Purchase"].plot(kind="pie",y="Purchase",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\3196987045.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Gender").sum()["Purchase"].plot(kind="pie",y="Purchase",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### Average amount spent by each gender

# %%
df.groupby("Gender").mean()["Purchase"].plot(kind="pie",y="Purchase",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\1255271694.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Gender").mean()["Purchase"].plot(kind="pie",y="Purchase",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### Analyzing Age and Marital Affair

# %%
df.groupby("Age").size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby("Age").size().plot(kind="bar",title="Purchase as per age")
# Out:
# <Axes: title={'center': 'Purchase as per age'}, xlabel='Age'>

# %% [markdown]
# ### we can say that the buyers ranging from age 26-35 are most likely to buy a product during black friday sale

# %%
df.groupby("Age").nunique()["Product_ID"]
# Out:
# Age
# 0-17     2300
# 18-25    3213
# 26-35    3419
# 36-45    3318
# 46-50    3099
# 51-55    2877
# 55+      2573
# Name: Product_ID, dtype: int64

# %%
df.groupby("Age").nunique()["Product_ID"].plot.bar("Age")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").mean()["Purchase"]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\2629338671.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Age").mean()["Purchase"]
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby("Age").mean()["Purchase"].plot(kind="pie",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\1181346863.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Age").mean()["Purchase"].plot(kind="pie",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Marital_Status").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.set(rc={"figure.figsize":(12,6)})
sns.countplot(x="Gender",hue="Age",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("City_Category").size().plot(kind="pie",autopct="%.1f")
# Out:
# <Axes: >

# %% [markdown]
# ### We can see that 42% of the people buying in black friday sales are from city B

# %%
sns.countplot(x="Gender",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind="pie",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\798257733.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("City_Category").sum()["Purchase"].plot(kind="pie",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %%
df.groupby("City_Category").mean()["Purchase"].plot(kind="pie",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\517179554.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("City_Category").mean()["Purchase"].plot(kind="pie",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### From the above two charts it can be observed that total amount spent is most in City B and least in City A but the average amount spent is approx same in both the city that concludes people in City A are buying more product but People in city A are buying expensive Products. The average cost spent is maximum for City C

# %%
sns.countplot(x="Marital_Status",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby("Marital_Status").sum()["Purchase"].plot(kind="pie",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\3925690702.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Marital_Status").sum()["Purchase"].plot(kind="pie",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x="City_Category",hue="Age",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# ### City A and C have approx same number of people in Age category 18-25 but city C has much more people in age category 36-45

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("Stay_In_Current_City_Years").size()
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# dtype: int64

# %%
df.groupby("Stay_In_Current_City_Years").size().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# ### From this we can say that targeting the Male who are unmarried and living in the city since an year are more likely to buy a product

# %%
# Checking the amount spent by Males who are unmarried and living in the city since an year

# %%
df_pr=df[df["Gender"]=="M"]

# %%
df_pr.groupby("Stay_In_Current_City_Years").sum()["Purchase"]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\1550045712.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_pr.groupby("Stay_In_Current_City_Years").sum()["Purchase"]
# Stay_In_Current_City_Years
# 0      528630216
# 1     1321077096
# 2      725224330
# 3      663184060
# 4+     614928655
# Name: Purchase, dtype: int64

# %%
df_pr.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind="pie",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\2865350447.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_pr.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind="pie",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %%
df_pr.groupby("Stay_In_Current_City_Years").mean()["Purchase"].plot(kind="pie",autopct="%.1f")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\1354354733.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_pr.groupby("Stay_In_Current_City_Years").mean()["Purchase"].plot(kind="pie",autopct="%.1f")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ### It can be seen that average price spent is same for the males irrespective of time spent in the city.

# %% [markdown]
# ### Analysis on basis of Occupation

# %%
df.groupby("Occupation").size().sort_values(ascending=True).plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# #### People with occupation 4 are buying the most number of products

# %%
df.groupby("Occupation").mean()["Purchase"].sort_values(ascending=True).plot(kind="bar")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\2842384157.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Occupation").mean()["Purchase"].sort_values(ascending=True).plot(kind="bar")
# <Axes: xlabel='Occupation'>

# %% [markdown]
# #### People with Occupation 17 are buying more expensive Products

# %%
sns.countplot(x="Occupation",hue="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# #### In occupation 4 there are mostly unmaried people

# %%
df.groupby("Product_Category_1").size()
# Out:
# Product_Category_1
# 1     138353
# 2      23499
# 3      19849
# 4      11567
# 5     148592
# 6      20164
# 7       3668
# 8     112132
# 9        404
# 10      5032
# 11     23960
# 12      3875
# 13      5440
# 14      1500
# 15      6203
# 16      9697
# 17       567
# 18      3075
# dtype: int64

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind="bar")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\1606550662.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind="bar")
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_ID").size().sort_values().nlargest(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# #### These are the top 10 hot selling products

# %%
df.groupby("Product_ID").sum()["Purchase"].sort_values().nlargest(10).plot(kind="bar")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\251530152.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_ID").sum()["Purchase"].sort_values().nlargest(10).plot(kind="bar")
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# #### These are the top 10 products on which people are spending the most

# %%
df.groupby("Product_ID").mean()["Purchase"].sort_values().nlargest(10).plot(kind="bar")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23060\3660585031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_ID").mean()["Purchase"].sort_values().nlargest(10).plot(kind="bar")
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# #### These are the most expensive products

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
l=[]
for i in range(len(df)):
    l.append(df["Gender"][i] + "_" + str(df["Marital_Status"][i]))
    
df["Gender_Marital"]=l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Gender_Marital
# 0            F_0
# 1            F_0
# 2            F_0
# 3            F_0
# 4            M_0

# %%
sns.countplot(x="Gender_Marital",data=df)
# Out:
# <Axes: xlabel='Gender_Marital', ylabel='count'>

# %%
sns.countplot(x="Occupation",hue="Gender_Marital",data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# ## CONCLUSION AND INSIGHTS

# %% [markdown]
# 1) Male to Female Ratio is approximately 3:1
# 2) Males are spending approx 3/4 of the total amount
# 3) Average Amount spent is same for both Males and Females which means Females are buying more expensive products
# 4) People from age group 26-35 are buying the most number of products
# 5) Average amount spent is approximately same for all the age groups
# 6) People Living in City B are buying and spending the most in the sale
# 7) Average price spent is More for City C
# 8) Ratio of unmaried to maried is 59:41
# 9) People living in the city since an year are spending 34% of the total amount
# 10) Top 3 hot selling products from category 1 are 1,5,8 and are also the products on which people are spending the most
# 11) Most products purhased are in order M_0>M_1>F_0>F_1
